# %% [markdown]
# # Claims Fraud Detection System - Demo Notebook
#
# This notebook demonstrates the fraud detection system for educational purposes.
#
# **⚠️ DISCLAIMER: This is for research and educational use only. Not for production use.**
